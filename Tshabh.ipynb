# %%
# !pip install Arabic-Stopwords
# !pip install qalsadi
# Out:
# Requirement already satisfied: Arabic-Stopwords in c:\users\hind\anaconda3\lib\site-packages (0.4.3)
# Requirement already satisfied: pyarabic>=0.6.2 in c:\users\hind\anaconda3\lib\site-packages (from Arabic-Stopwords) (0.6.15)
# Requirement already satisfied: six>=1.14.0 in c:\users\hind\anaconda3\lib\site-packages (from pyarabic>=0.6.2->Arabic-Stopwords) (1.16.0)
# Requirement already satisfied: qalsadi in c:\users\hind\anaconda3\lib\site-packages (0.5)
# Requirement already satisfied: Arabic-Stopwords>=0.4.2 in c:\users\hind\anaconda3\lib\site-packages (from qalsadi) (0.4.3)
# Requirement already satisfied: alyahmor>=0.2 in c:\users\hind\anaconda3\lib\site-packages (from qalsadi) (0.2)
# Requirement already satisfied: arramooz-pysqlite>=0.4.2 in c:\users\hind\anaconda3\lib\site-packages (from qalsadi) (0.4.2)
# Requirement already satisfied: codernitydb3 in c:\users\hind\anaconda3\lib\site-packages (from qalsadi) (0.6.0)
# Requirement already satisfied: libqutrub>=1.2.3 in c:\users\hind\anaconda3\lib\site-packages (from qalsadi) (1.2.4.1)
# Requirement already satisfied: mysam-tagmanager>=0.3.3 in c:\users\hind\anaconda3\lib\site-packages (from qalsadi) (0.4)
# Requirement already satisfied: naftawayh>=0.3 in c:\users\hind\anaconda3\lib\site-packages (from qalsadi) (0.4)
# Requirement already satisfied: pickledb>=0.9.2 in c:\users\hind\anaconda3\lib\site-packages (from qalsadi) (0.9.2)
# Requirement already satisfied: pyarabic>=0.6.7 in c:\users\hind\anaconda3\lib\site-packages (from qalsadi) (0.6.15)
# Requirement already satisfied: tashaphyne>=0.3.4.1 in c:\users\hind\anaconda3\lib\site-packages (from qalsadi) (0.3.6)
# Requirement already satisfied: six>=1.14.0 in c:\users\hind\anaconda3\lib\site-packages (from pyarabic>=0.6.7->qalsadi) (1.16.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
import requests
from bs4 import BeautifulSoup

import pyarabic.araby as araby
from nltk.corpus import stopwords # arabic stopwords
import arabicstopwords.arabicstopwords as stp # arabic stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem.snowball import ArabicStemmer # Arabic Stemmer gets rot word
import qalsadi.lemmatizer
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
df = pd.read_csv("Arabic-Original.csv", header = None, names = ['text'])

# %%
df.head()
# Out:
#                                            text
# 0    1|1|بِسْمِ اللَّهِ الرَّحْمَٰنِ الرَّحِيمِ
# 1     1|2|الْحَمْدُ لِلَّهِ رَبِّ الْعَالَمِينَ
# 2                   1|3|الرَّحْمَٰنِ الرَّحِيمِ
# 3                   1|4|مَالِكِ يَوْمِ الدِّينِ
# 4  1|5|إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ

# %%
df = df['text'].str.split('|', expand=True)

# %%
df.columns = ['surah_num', 'ayah_num', 'ayah_txt']
df['surah_num'] = df['surah_num'].astype('int')
df['ayah_num'] = df['ayah_num'].astype('int')

# %%
df.head()
# Out:
#    surah_num  ayah_num                                  ayah_txt
# 0          1         1    بِسْمِ اللَّهِ الرَّحْمَٰنِ الرَّحِيمِ
# 1          1         2     الْحَمْدُ لِلَّهِ رَبِّ الْعَالَمِينَ
# 2          1         3                   الرَّحْمَٰنِ الرَّحِيمِ
# 3          1         4                   مَالِكِ يَوْمِ الدِّينِ
# 4          1         5  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6236 entries, 0 to 6235
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   surah_num  6236 non-null   int32
#  1   ayah_num   6236 non-null   int32
#  2   ayah_txt   6236 non-null   object
# dtypes: int32(2), object(1)
# memory usage: 97.6+ KB

# %%
df.describe()
# Out:
#          surah_num     ayah_num
# count  6236.000000  6236.000000
# mean     33.519724    53.506575
# std      26.461261    50.463924
# min       1.000000     1.000000
# 25%      11.000000    16.000000
# 50%      26.000000    38.000000
# 75%      51.000000    75.000000
# max     114.000000   286.000000

# %% [markdown]
# # Cleaning

# %%
def normalize_text(txt):
    txt = re.sub("[إأٱآا]", "ا", txt)
    txt = re.sub("ى", "ي", txt)
    txr = re.sub("ة", "ه", txt)
    return txt

# %%
stopword = set(list(stp.stopwords_list())
              + stopwords.words('arabic'))
stopword = [normalize_text(word) for word in stopword]

# %%
#الهدف منه يرجع الكلمة لأصلها
st = ArabicStemmer()
lemmer = qalsadi.lemmatizer.Lemmatizer()

# %%
def clean_txt(txt):
    #إزالة التشكيل والتتويل
    txt = araby.strip_diacritics(txt)
    txt = araby.strip_tatweel(txt)
    
    
    txt = normalize_text(txt)
    
    #remove stop words and punctuation
    txt = ' '.join([token.translate(str.maketrans
    ('','',string.punctuation)) 
                    for token in txt.split(' ')
                   if token not in stopword])
    
    txt_lemmatized = ' '.join([lemmer.lemmatize(token) 
                 for token in txt.split(' ')])
    return txt+" "+txt_lemmatized

# %%
df['clean_txt'] = df['ayah_txt'].apply(lambda x: clean_txt(x))

# %%
df.sample(1)
# Out:
#       surah_num  ayah_num                                           ayah_txt  \
# 1155          7       202  وَإِخْوَانُهُمْ يَمُدُّونَهُمْ فِي الْغَيِّ ثُ...
#
#                                              clean_txt
# 1155  واخوانهم يمدونهم الغي يقصرون واخوانهم أمد غي قصر

# %% [markdown]
# # Add Surah Names

# %%
surah_names = ['الفاتحة',
 'البقرة',
 'آل عمران',
 'النساء',
 'المائدة',
 'الأنعام',
 'الأعراف',
 'الأنفال',
 'التوبة',
 'يونس',
 'هود',
 'يوسف',
 'الرعد',
 'إبراهيم',
 'الحجر',
 'النحل',
 'الإسراء',
 'الكهف',
 'مريم',
 'طه',
 'الأنبياء',
 'الحج',
 'المؤمنون',
 'النور',
 'الفرقان',
 'الشعراء',
 'النمل',
 'القصص',
 'العنكبوت',
 'الروم',
 'لقمان',
 'السجدة',
 'الأحزاب',
 'سبأ',
 'فاطر',
 'يس',
 'الصافات',
 'ص',
 'الزمر',
 'غافر',
 'فصلت',
 'الشورى',
 'الزخرف',
 'الدخان',
 'الجاثية',
 'الأحقاف',
 'محمد',
 'الفتح',
 'الحجرات',
 'ق',
 'الذاريات',
 'الطور',
 'النجم',
 'القمر',
 'الرحمن',
 'الواقعة',
 'الحديد',
 'المجادلة',
 'الحشر',
 'الممتحنة',
 'الصف',
 'الجمعة',
 'المنافقون',
 'التغابن',
 'الطلاق',
 'التحريم',
 'الملك',
 'القلم',
 'الحاقة',
 'المعارج',
 'نوح',
 'الجن',
 'المزمل',
 'المدثر',
 'القيامة',
 'الإنسان',
 'المرسلات',
 'النبأ',
 'النازعات',
 'عبس',
 'التكوير',
 'الإنفطار',
 'المطففين',
 'الانشقاق',
 'البروج',
 'الطارق',
 'الأعلى',
 'الغاشية',
 'الفجر',
 'البلد',
 'الشمس',
 'الليل',
 'الضحى',
 'الشرح',
 'التين',
 'العلق',
 'القدر',
 'البينة',
 'الزلزلة',
 'العاديات',
 'القارعة',
 'التكاثر',
 'العصر',
 'الهمزة',
 'الفيل',
 'قريش',
 'الماعون',
 'الكوثر',
 'الكافرون',
 'النصر',
 'المسد',
 'الإخلاص',
 'الفلق',
 'الناس']

surah_names
# Out:
# ['الفاتحة',
#  'البقرة',
#  'آل عمران',
#  'النساء',
#  'المائدة',
#  'الأنعام',
#  'الأعراف',
#  'الأنفال',
#  'التوبة',
#  'يونس',
#  'هود',
#  'يوسف',
#  'الرعد',
#  'إبراهيم',
#  'الحجر',
#  'النحل',
#  'الإسراء',
#  'الكهف',
#  'مريم',
#  'طه',
#  'الأنبياء',
#  'الحج',
#  'المؤمنون',
#  'النور',
#  'الفرقان',
#  'الشعراء',
#  'النمل',
#  'القصص',
#  'العنكبوت',
#  'الروم',
#  'لقمان',
#  'السجدة',
#  'الأحزاب',
#  'سبأ',
#  'فاطر',
#  'يس',
#  'الصافات',
#  'ص',
#  'الزمر',
#  'غافر',
#  'فصلت',
#  'الشورى',
#  'الزخرف',
#  'الدخان',
#  'الجاثية',
#  'الأحقاف',
#  'محمد',
#  'الفتح',
#  'الحجرات',
#  'ق',
#  'الذاريات',
#  'الطور',
#  'النجم',
#  'القمر',
#  'الرحمن',
#  'الواقعة',
#  'الحديد',
#  'المجادلة',
#  'الحشر',
#  'الممتحنة',
#  'الصف',
#  'الجمعة',
#  'المنافقون',
#  'التغابن',
#  'الطلاق',
#  'التحريم',
#  'الملك',
#  'القلم',
#  'الحاقة',
#  'المعارج',
#  'نوح',
#  'الجن',
#  'المزمل',
#  'المدثر',
#  'القيامة',
#  'الإنسان',
#  'المرسلات',
#  'النبأ',
#  'النازعات',
#  'عبس',
#  'التكوير',
#  'الإنفطار',
#  'المطففين',
#  'الانشقاق',
#  'البروج',
#  'الطارق',
#  'الأعلى',
#  'الغاشية',
#  'الفجر',
#  'البلد',
#  'الشمس',
#  'الليل',
#  'الضحى',
#  'الشرح',
#  'التين',
#  'العلق',
#  'القدر',
#  'البينة',
#  'الزلزلة',
#  'العاديات',
#  'القارعة',
#  'التكاثر',
#  'العصر',
#  'الهمزة',
#  'الفيل',
#  'قريش',
#  'الماعون',
#  'الكوثر',
#  'الكافرون',
#  'النصر',
#  'المسد',
#  'الإخلاص',
#  'الفلق',
#  'الناس']

# %%
df['surah_names'] = df['surah_num'].apply(lambda x: surah_names[x-1])

# %%
df.sample(1)
# Out:
#       surah_num  ayah_num                                    ayah_txt  \
# 3821         37        34  إِنَّا كَذَٰلِكَ نَفْعَلُ بِالْمُجْرِمِينَ
#
#                     clean_txt surah_names
# 3821  نفعل بالمجرمين فعل مجرم     الصافات

# %% [markdown]
# # Grouping by Surah name

# %%
group_surah = {'surah_num': [],'surah_name': [], 'surah_txt': []}

# %%
for i in range(1,df['surah_num'].max()+1):
    surah_txt = ' '.join(df[df['surah_num']==i]['ayah_txt'].to_list())
    group_surah['surah_txt'].append(surah_txt)
    group_surah['surah_num'].append(i)
    group_surah['surah_name'].append(surah_names[i-1])

# %%
df_surah = pd.DataFrame(group_surah)

# %%
df_surah.sample(1)
# Out:
#      surah_num surah_name                                          surah_txt
# 102        103      العصر  بِسْمِ اللَّهِ الرَّحْمَٰنِ الرَّحِيمِ وَالْعَ...

# %%
df_surah.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   surah_num   114 non-null    int64
#  1   surah_name  114 non-null    object
#  2   surah_txt   114 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.8+ KB

# %% [markdown]
# # Similarity

# %%
# apply the TfidfVectorizer to the corpus
corpus = df['clean_txt']
vectorizer = TfidfVectorizer(ngram_range=(1,2))
corpus_vectorized = vectorizer.fit_transform(corpus)
print(corpus_vectorized.shape)
# Out:
# (6236, 75285)

# %%
vectorizer.get_feature_names_out()[:20]
# Out:
# array(['آتى', 'آتى أجزى', 'آتى اتوا', 'آتى اجرا', 'آتى اجرها',
#        'آتى اجرهم', 'آتى اجوركم', 'آتى اجورهم', 'آتى احدا', 'آتى الاخرة',
#        'آتى الله', 'آتى اوتي', 'آتى اوتيتم', 'آتى باذن', 'آتى تب',
#        'آتى حذر', 'آتى حكم', 'آتى خير', 'آتى ردى', 'آتى زكاة'],
#       dtype=object)

# %%
def show_best_results(df_quran, scores_array, threshold_low=0.881, threshold_high=0.990, top_n=3):
    # Reset the index of df_quran to ensure correct alignment
    df_quran_reset = df_quran.reset_index(drop=True)

    # Sort the indices based on scores_array
    sorted_indices = np.argsort(scores_array)[::-1]

    # Display only the top_n results within the specified score range
    displayed_count = 0
    for idx in sorted_indices:
        score = scores_array[idx]

        # Use iloc to access the DataFrame by integer position
        row = df_quran_reset.iloc[idx]
        ayah = row["ayah_txt"]
        ayah_num = row["ayah_num"]
        surah_name = row["surah_names"]

        if threshold_low <= score <= threshold_high:
            print(ayah)
            print(f'أيه رقم {ayah_num}  سورة {surah_name}')
            print(f"Similarity Score: {score:.4f}")
            print("====================================")

            displayed_count += 1
            if displayed_count >= top_n:
                break

# %%
def run_tfidf_optimized(name, threshold_low, threshold_high, top_n=5):
    # Filter rows based on the condition
    condition = df['surah_names'].str.contains(name)
    new_df = df[condition].copy()

    # Precompute TF-IDF vectors for the entire corpus
    corpus_vectorized = vectorizer.transform(df['clean_txt'])

    for _, row in new_df.iterrows():
        query = row['clean_txt']
        query_vectorized = vectorizer.transform([query])

        # Calculate cosine similarities using linear_kernel
        cosine_similarities = linear_kernel(query_vectorized, corpus_vectorized).flatten()

        # Pass the scores to the optimized show_best_results function
        show_best_results(df, cosine_similarities, threshold_low=threshold_low, threshold_high=threshold_high, top_n=top_n)

# %%
name=input(":اكتب اسم السوره المراده")
run_tfidf_optimized(name, threshold_low=0.555, threshold_high=1, top_n=5)
# Out:
# :اكتب اسم السوره المرادهالصافات
# فَالزَّاجِرَاتِ زَجْرًا
# أيه رقم 2  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَالتَّالِيَاتِ ذِكْرًا
# أيه رقم 3  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِنَّ إِلَٰهَكُمْ لَوَاحِدٌ
# أيه رقم 4  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# رَبُّ السَّمَاوَاتِ وَالْأَرْضِ وَمَا بَيْنَهُمَا وَرَبُّ الْمَشَارِقِ
# أيه رقم 5  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِنَّا زَيَّنَّا السَّمَاءَ الدُّنْيَا بِزِينَةٍ الْكَوَاكِبِ
# أيه رقم 6  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَحِفْظًا مِنْ كُلِّ شَيْطَانٍ مَارِدٍ
# أيه رقم 7  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# دُحُورًا ۖ وَلَهُمْ عَذَابٌ وَاصِبٌ
# أيه رقم 9  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِلَّا مَنْ خَطِفَ الْخَطْفَةَ فَأَتْبَعَهُ شِهَابٌ ثَاقِبٌ
# أيه رقم 10  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# بَلْ عَجِبْتَ وَيَسْخَرُونَ
# أيه رقم 12  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَإِذَا ذُكِّرُوا لَا يَذْكُرُونَ
# أيه رقم 13  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَقَالُوا إِنْ هَٰذَا إِلَّا سِحْرٌ مُبِينٌ
# أيه رقم 15  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# أَإِذَا مِتْنَا وَكُنَّا تُرَابًا وَعِظَامًا أَإِنَّا لَمَبْعُوثُونَ
# أيه رقم 16  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# قَالُوا أَإِذَا مِتْنَا وَكُنَّا تُرَابًا وَعِظَامًا أَإِنَّا لَمَبْعُوثُونَ
# أيه رقم 82  سورة المؤمنون
# Similarity Score: 0.9022
# ====================================
# أَإِذَا مِتْنَا وَكُنَّا تُرَابًا وَعِظَامًا أَإِنَّا لَمَدِينُونَ
# أيه رقم 53  سورة الصافات
# Similarity Score: 0.7837
# ====================================
# وَكَانُوا يَقُولُونَ أَئِذَا مِتْنَا وَكُنَّا تُرَابًا وَعِظَامًا أَإِنَّا لَمَبْعُوثُونَ
# أيه رقم 47  سورة الواقعة
# Similarity Score: 0.6345
# ====================================
# أَإِذَا مِتْنَا وَكُنَّا تُرَابًا ۖ ذَٰلِكَ رَجْعٌ بَعِيدٌ
# أيه رقم 3  سورة ق
# Similarity Score: 0.6187
# ====================================
# قُلْ نَعَمْ وَأَنْتُمْ دَاخِرُونَ
# أيه رقم 18  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَإِنَّمَا هِيَ زَجْرَةٌ وَاحِدَةٌ فَإِذَا هُمْ يَنْظُرُونَ
# أيه رقم 19  سورة الصافات
# Similarity Score: 1.0000
# ====================================
سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فِي جَنَّاتِ النَّعِيمِ
# أيه رقم 43  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فِي جَنَّاتِ النَّعِيمِ
# أيه رقم 12  سورة الواقعة
# Similarity Score: 1.0000
# ====================================
# يُطَافُ عَلَيْهِمْ بِكَأْسٍ مِنْ مَعِينٍ
# أيه رقم 45  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# بَيْضَاءَ لَذَّةٍ لِلشَّارِبِينَ
# أيه رقم 46  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# لَا فِيهَا غَوْلٌ وَلَا هُمْ عَنْهَا يُنْزَفُونَ
# أيه رقم 47  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَعِنْدَهُمْ قَاصِرَاتُ الطَّرْفِ عِينٌ
# أيه رقم 48  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَعِنْدَهُمْ قَاصِرَاتُ الطَّرْفِ أَتْرَابٌ
# أيه رقم 52  سورة ص
# Similarity Score: 0.5874
# ====================================
# كَأَنَّهُنَّ بَيْضٌ مَكْنُونٌ
# أيه رقم 49  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَأَقْبَلَ بَعْضُهُمْ عَلَىٰ بَعْضٍ يَتَسَاءَلُونَ
# أيه رقم 50  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَأَقْبَلَ بَعْضُهُمْ عَلَىٰ بَعْضٍ يَتَسَاءَلُونَ
# أيه رقم 27  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَأَقْبَلَ بَعْضُهُمْ عَلَىٰ بَعْضٍ يَتَسَاءَلُونَ
# أيه رقم 25  سورة الطور
# Similarity Score: 1.0000
# ====================================
# قَالَ قَائِلٌ مِنْهُمْ إِنِّي كَانَ لِي قَرِينٌ
# أيه رقم 51  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# أَإِذَا مِتْنَا وَكُنَّا تُرَابًا وَعِظَامًا أَإِنَّا لَمَبْعُوثُونَ
# أيه رقم 16  سورة الصافات
# Similarity Score: 0.7837
# ====================================
# قَالُوا أَإِذَا مِتْنَا وَكُنَّا تُرَابًا وَعِظَامًا أَإِنَّا لَمَبْعُوثُونَ
# أيه رقم 82  سورة المؤمنون
# Similarity Score: 0.7446
# ====================================
# أَإِذَا مِتْنَا وَكُنَّا تُرَابًا ۖ ذَٰلِكَ رَجْعٌ بَعِيدٌ
# أيه رقم 3  سورة ق
# Similarity Score: 0.6131
# ====================================
# فَاطَّلَعَ فَرَآهُ فِي سَوَاءِ الْجَحِيمِ
# أيه رقم 55  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَلَوْلَا نِعْمَةُ رَبِّي لَكُنْتُ مِنَ الْمُحْضَرِينَ
# أيه رقم 57  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# أَفَمَا نَحْنُ بِمَيِّتِينَ
# أيه رقم 58  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِلَّا مَوْتَتَنَا الْأُولَىٰ وَمَا نَحْنُ بِمُعَذَّبِينَ
# أيه رقم 59  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِنَّ هَٰذَا لَهُوَ الْفَوْزُ الْعَظِيمُ
# أيه رقم 60  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَضْلًا مِنْ رَبِّكَ ۚ ذَٰلِكَ هُوَ الْفَوْزُ الْعَظِيمُ
# أيه رقم 57  سورة الدخان
# Similarity Score: 0.6031
# ====================================
# أَذَٰلِكَ خَيْرٌ نُزُلًا أَمْ شَجَرَةُ الزَّقُّومِ
# أيه رقم 62  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِنَّا جَعَلْنَاهَا فِتْنَةً لِلظَّالِمِينَ
# أيه رقم 63  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إ
سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِنَّا كَذَٰلِكَ نَجْزِي الْمُحْسِنِينَ
# أيه رقم 80  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# كَذَٰلِكَ نَجْزِي الْمُحْسِنِينَ
# أيه رقم 110  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# ثُمَّ أَغْرَقْنَا الْآخَرِينَ
# أيه رقم 82  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# ثُمَّ أَغْرَقْنَا الْآخَرِينَ
# أيه رقم 66  سورة الشعراء
# Similarity Score: 1.0000
# ====================================
# وَإِنَّ مِنْ شِيعَتِهِ لَإِبْرَاهِيمَ
# أيه رقم 83  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِذْ جَاءَ رَبَّهُ بِقَلْبٍ سَلِيمٍ
# أيه رقم 84  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِذْ قَالَ لِأَبِيهِ وَقَوْمِهِ مَا تَعْبُدُونَ
# أيه رقم 70  سورة الشعراء
# Similarity Score: 1.0000
# ====================================
# إِذْ قَالَ لِأَبِيهِ وَقَوْمِهِ مَاذَا تَعْبُدُونَ
# أيه رقم 85  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# أَئِفْكًا آلِهَةً دُونَ اللَّهِ تُرِيدُونَ
# أيه رقم 86  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَمَا ظَنُّكُمْ بِرَبِّ الْعَالَمِينَ
# أيه رقم 87  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَنَظَرَ نَظْرَةً فِي النُّجُومِ
# أيه رقم 88  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَقَالَ إِنِّي سَقِيمٌ
# أيه رقم 89  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَتَوَلَّوْا عَنْهُ مُدْبِرِينَ
# أيه رقم 90  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَرَاغَ إِلَىٰ آلِهَتِهِمْ فَقَالَ أَلَا تَأْكُلُونَ
# أيه رقم 91  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# مَا لَكُمْ لَا تَنْطِقُونَ
# أيه رقم 92  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَرَاغَ عَلَيْهِمْ ضَرْبًا بِالْيَمِينِ
# أيه رقم 93  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَأَقْبَلُوا إِلَيْهِ يَزِفُّونَ
# أيه رقم 94  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# قَالَ أَتَعْبُدُونَ مَا تَنْحِتُونَ
# أيه رقم 95  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَاللَّهُ خَلَقَكُمْ وَمَا تَعْمَلُونَ
# أيه رقم 96  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# قَالُوا ابْنُوا لَهُ بُنْيَانًا فَأَلْقُوهُ فِي الْجَحِيمِ
# أيه رقم 97  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَأَرَادُوا بِهِ كَيْدًا فَجَعَلْنَاهُمُ الْأَسْفَلِينَ
# أيه رقم 98  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَقَالَ إِنِّي ذَاهِبٌ إِلَىٰ رَبِّي سَيَهْدِينِ
# أيه رقم 99  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# رَبِّ هَبْ لِي مِنَ الصَّالِحِينَ
# أيه رقم 100  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَبَشَّرْنَاهُ بِغُلَامٍ حَلِيمٍ
# أيه رقم 101  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَلَمَّا بَلَغَ مَعَهُ السَّعْيَ قَالَ يَا بُنَيَّ إِنِّي أَرَىٰ فِي الْمَنَامِ أَنِّي أَذْبَحُكَ فَانْظُرْ مَاذَا تَرَىٰ ۚ قَالَ يَا أَبَتِ افْعَلْ مَا تُؤْمَرُ ۖ سَتَجِدُنِي إِنْ شَاءَ اللَّهُ مِنَ الصَّابِرِينَ
# أيه رقم 102  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَلَمَّا أَسْلَمَا وَتَلَّهُ لِلْجَبِينِ
# أيه رقم 103  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# و
سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِذْ قَالَ لِقَوْمِهِ أَلَا تَتَّقُونَ
# أيه رقم 124  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# اللَّهَ رَبَّكُمْ وَرَبَّ آبَائِكُمُ الْأَوَّلِينَ
# أيه رقم 126  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# قَالَ رَبُّكُمْ وَرَبُّ آبَائِكُمُ الْأَوَّلِينَ
# أيه رقم 26  سورة الشعراء
# Similarity Score: 0.8137
# ====================================
# لَا إِلَٰهَ إِلَّا هُوَ يُحْيِي وَيُمِيتُ ۖ رَبُّكُمْ وَرَبُّ آبَائِكُمُ الْأَوَّلِينَ
# أيه رقم 8  سورة الدخان
# Similarity Score: 0.7104
# ====================================
# إِلَّا عِبَادَ اللَّهِ الْمُخْلَصِينَ
# أيه رقم 160  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِلَّا عِبَادَ اللَّهِ الْمُخْلَصِينَ
# أيه رقم 74  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِلَّا عِبَادَ اللَّهِ الْمُخْلَصِينَ
# أيه رقم 40  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِلَّا عِبَادَ اللَّهِ الْمُخْلَصِينَ
# أيه رقم 128  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# لَكُنَّا عِبَادَ اللَّهِ الْمُخْلَصِينَ
# أيه رقم 169  سورة الصافات
# Similarity Score: 0.7384
# ====================================
# وَتَرَكْنَا عَلَيْهِ فِي الْآخِرِينَ
# أيه رقم 108  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَتَرَكْنَا عَلَيْهِ فِي الْآخِرِينَ
# أيه رقم 78  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَتَرَكْنَا عَلَيْهِ فِي الْآخِرِينَ
# أيه رقم 129  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَتَرَكْنَا عَلَيْهِمَا فِي الْآخِرِينَ
# أيه رقم 119  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِنَّا كَذَٰلِكَ نَجْزِي الْمُحْسِنِينَ
# أيه رقم 121  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِنَّا كَذَٰلِكَ نَجْزِي الْمُحْسِنِينَ
# أيه رقم 44  سورة المرسلات
# Similarity Score: 1.0000
# ====================================
# إِنَّا كَذَٰلِكَ نَجْزِي الْمُحْسِنِينَ
# أيه رقم 131  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِنَّا كَذَٰلِكَ نَجْزِي الْمُحْسِنِينَ
# أيه رقم 80  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# كَذَٰلِكَ نَجْزِي الْمُحْسِنِينَ
# أيه رقم 110  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَإِنَّ لُوطًا لَمِنَ الْمُرْسَلِينَ
# أيه رقم 133  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَنَجَّيْنَاهُ وَأَهْلَهُ أَجْمَعِينَ
# أيه رقم 170  سورة الشعراء
# Similarity Score: 0.8524
# ====================================
# إِلَّا عَجُوزًا فِي الْغَابِرِينَ
# أيه رقم 135  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِلَّا عَجُوزًا فِي الْغَابِرِينَ
# أيه رقم 171  سورة الشعراء
# Similarity Score: 1.0000
# ====================================
# ثُمَّ دَمَّرْنَا الْآخَرِينَ
# أيه رقم 136  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# ثُمَّ دَمَّرْنَا الْآخَرِينَ
# أيه رقم 172  سورة الشعراء
# Similarity Score: 1.0000
# ====================================
# وَإِنَّكُمْ لَتَمُرُّونَ عَلَيْهِمْ مُصْبِحِينَ
# أيه رقم 137  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَإِنَّ يُونُسَ لَمِنَ الْمُرْسَلِينَ
# أيه رقم 139  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِذْ أَبَقَ إِلَى الْفُلْكِ الْمَشْحُونِ
# أيه رقم 140  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَالْتَقَمَهُ الْحُوتُ وَهُوَ مُلِيمٌ
# أيه رقم 142  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَلَوْلَا أَنَّهُ كَانَ مِنَ الْمُسَبِّحِينَ
# أيه رقم 143  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# لَلَبِثَ فِي بَطْنِهِ إِلَىٰ يَوْمِ يُبْعَثُونَ
# أيه رقم 144  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَنَبَذْنَاهُ بِالْعَرَاءِ وَهُوَ سَقِيمٌ
# أيه رقم 145  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَأَنْبَتْنَا عَلَيْهِ شَجَرَةً مِنْ يَقْطِينٍ
# أيه رقم 146  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَأَرْسَلْنَاهُ إِلَىٰ مِائَةِ أَلْفٍ أَوْ يَزِيدُونَ
# أيه رقم 147  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَآمَنُوا فَمَتَّعْنَاهُمْ إِلَىٰ حِينٍ
# أيه رقم 148  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَاسْتَفْتِهِمْ أَلِرَبِّكَ الْبَنَاتُ وَلَهُمُ الْبَنُونَ
# أيه رقم 149  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# أَمْ لَهُ الْبَنَاتُ وَلَكُمُ الْبَنُونَ
# أيه رقم 39  سورة الطور
# Similarity Score: 0.5552
# ====================================
# إِنَّ هَٰؤُلَاءِ لَيَقُولُونَ
# أيه رقم 34  سورة الدخان
# Similarity Score: 1.0000
# ====================================
# أَلَا إِنَّهُمْ مِنْ إِفْكِهِمْ لَيَقُولُونَ
# أيه رقم 151  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَلَدَ اللَّهُ وَإِنَّهُمْ لَكَاذِبُونَ
# أيه رقم 152  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# أَصْطَفَى الْبَنَاتِ عَلَى الْبَنِينَ
# أيه رقم 153  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# مَا لَكُمْ كَيْفَ تَحْكُمُونَ
# أيه رقم 36  سورة القلم
# Similarity Score: 1.0000
# ====================================
# مَا لَكُمْ كَيْفَ تَحْكُمُونَ
# أيه رقم 154  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# أَفَلَا تَذَكَّرُونَ
# أيه رقم 155  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# أَمْ لَكُمْ سُلْطَانٌ مُبِينٌ
# أيه رقم 156  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَأْتُوا بِكِتَابِكُمْ إِنْ كُنْتُمْ صَادِقِينَ
# أيه رقم 157  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَجَعَلُوا بَيْنَهُ وَبَيْنَ الْجِنَّةِ نَسَبًا ۚ وَلَقَدْ عَلِمَتِ الْجِنَّةُ إِنَّهُمْ لَمُحْضَرُونَ
# أيه رقم 158  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# سُبْحَانَ اللَّهِ عَمَّا يَصِفُونَ
# أيه رقم 159  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِلَّا عِبَادَ اللَّهِ الْمُخْلَصِينَ
# أيه رقم 160  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِلَّا عِبَادَ اللَّهِ الْمُخْلَصِينَ
# أيه رقم 74  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِلَّا عِبَادَ اللَّهِ الْمُخْلَصِينَ
# أيه رقم 40  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِلَّا عِبَادَ اللَّهِ الْمُخْلَصِينَ
# أيه رقم 128  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# لَكُنَّا عِبَادَ اللَّهِ الْمُخْلَصِينَ
# أيه رقم 169  سورة الصافات
# Similarity Score: 0.7384
# ====================================
# لَا أَعْبُدُ مَا تَعْبُدُونَ
# أيه رقم 2  سورة الكافرون
# Similarity Score: 0.6945
# ====================================
# مَا أَنْتُمْ عَلَيْهِ بِفَاتِنِينَ
# أيه رقم 162  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِلَّا مَنْ هُوَ صَالِ الْجَحِيمِ
# أيه رقم 163  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَمَا مِنَّا إِلَّا لَهُ مَقَامٌ مَعْلُومٌ
# أيه رقم 164  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَإِنَّا لَنَحْنُ الصَّافُّونَ
# أيه رقم 165  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَإِنَّا لَنَحْنُ الْمُسَبِّحُونَ
# أيه رقم 166  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَإِنْ كَانُوا لَيَقُولُونَ
# أيه رقم 167  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# لَوْ أَنَّ عِنْدَنَا ذِكْرًا مِنَ الْأَوَّلِينَ
# أيه رقم 168  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# لَكُنَّا عِبَادَ اللَّهِ الْمُخْلَصِينَ
# أيه رقم 169  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِلَّا عِبَادَ اللَّهِ الْمُخْلَصِينَ
# أيه رقم 74  سورة الصافات
# Similarity Score: 0.7384
# ====================================
# إِلَّا عِبَادَ اللَّهِ الْمُخْلَصِينَ
# أيه رقم 160  سورة الصافات
# Similarity Score: 0.7384
# ====================================
# إِلَّا عِبَادَ اللَّهِ الْمُخْلَصِينَ
# أيه رقم 40  سورة الصافات
# Similarity Score: 0.7384
# ====================================
# إِلَّا عِبَادَ اللَّهِ الْمُخْلَصِينَ
# أيه رقم 128  سورة الصافات
# Similarity Score: 0.7384
# ====================================
# فَكَفَرُوا بِهِ ۖ فَسَوْفَ يَعْلَمُونَ
# أيه رقم 170  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَلَقَدْ سَبَقَتْ كَلِمَتُنَا لِعِبَادِنَا الْمُرْسَلِينَ
# أيه رقم 171  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# إِنَّهُمْ لَهُمُ الْمَنْصُورُونَ
# أيه رقم 172  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَإِنَّ جُنْدَنَا لَهُمُ الْغَالِبُونَ
# أيه رقم 173  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# فَتَوَلَّ عَنْهُمْ حَتَّىٰ حِينٍ
# أيه رقم 174  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَأَبْصِرْهُمْ فَسَوْفَ يُبْصِرُونَ
# أيه رقم 175  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَأَبْصِرْ فَسَوْفَ يُبْصِرُونَ
# أيه رقم 179  سورة الصافات
# Similarity Score: 0.6806
# ====================================
# فَإِذَا نَزَلَ بِسَاحَتِهِمْ فَسَاءَ صَبَاحُ الْمُنْذَرِينَ
# أيه رقم 177  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَتَوَلَّ عَنْهُمْ حَتَّىٰ حِينٍ
# أيه رقم 178  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَأَبْصِرْ فَسَوْفَ يُبْصِرُونَ
# أيه رقم 179  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَأَبْصِرْهُمْ فَسَوْفَ يُبْصِرُونَ
# أيه رقم 175  سورة الصافات
# Similarity Score: 0.6806
# ====================================
# سُبْحَانَ رَبِّكَ رَبِّ الْعِزَّةِ عَمَّا يَصِفُونَ
# أيه رقم 180  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَسَلَامٌ عَلَى الْمُرْسَلِينَ
# أيه رقم 181  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# وَالْحَمْدُ لِلَّهِ رَبِّ الْعَالَمِينَ
# أيه رقم 182  سورة الصافات
# Similarity Score: 1.0000
# ====================================
# الْحَمْدُ لِلَّهِ رَبِّ الْعَالَمِينَ
# أيه رقم 2  سورة الفاتحة
# Similarity Score: 0.7617
# ====================================
